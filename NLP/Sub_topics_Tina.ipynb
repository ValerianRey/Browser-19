# %%
from os.path import join as pj
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
import nltk
nltk.download('wordnet')
from sklearn.model_selection import train_test_split
np.random.seed(400)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\tr\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
path = 'C:/Users/tr/CodeVsCovid19/data'
file_name = 'metadata_en_topics.csv'
df_meta = pd.read_csv(pj(path, file_name))

# %%
df_meta.main_topic.value_counts()
# Out:
# 7    7669
# 2    6347
# 0    5255
# 4    4638
# 5    4615
# 3    3389
# 1    3078
# 6    2109
# Name: main_topic, dtype: int64

# %%
def lemmatize_stemming(text):
    return PorterStemmer().stem(WordNetLemmatizer().lemmatize(text, pos='v'))
# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
            
    return result

# %% [markdown]
# Subtopics  of topic 0 :

# %%
processed_docs=[]
for t in df_meta[df_meta.main_topic==0].abstract:
    processed_docs.append(preprocess(t))
    
dictionary = gensim.corpora.Dictionary(processed_docs)
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
lda_model_0 =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
for idx, topic in lda_model_0.print_topics(-1):
    print("Topic {}: \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic 0:
# Words: 0.016*"rat" + 0.013*"neutrophil" + 0.013*"pulmonari" + 0.012*"tumor" + 0.011*"case" + 0.011*"liver" + 0.010*"injuri" + 0.010*"alveolar" + 0.008*"pneumonia" + 0.006*"damag"
#
#
# Topic 1:
# Words: 0.034*"influenza" + 0.020*"adjuv" + 0.010*"resist" + 0.010*"cat" + 0.008*"felin" + 0.008*"balb" + 0.007*"alpha" + 0.007*"titer" + 0.006*"suscept" + 0.006*"assay"
#
#
# Topic 2:
# Words: 0.015*"angiotensin" + 0.011*"zikv" + 0.010*"intestin" + 0.010*"epitheli" + 0.008*"enzym" + 0.006*"diabet" + 0.006*"organ" + 0.006*"kidney" + 0.005*"alter" + 0.005*"sar"
#
#
# Topic 3:
# Words: 0.024*"vector" + 0.017*"mucos" + 0.016*"recombin" + 0.011*"attenu" + 0.011*"intranas" + 0.010*"immunogen" + 0.010*"elicit" + 0.010*"deliveri" + 0.009*"boost" + 0.008*"efficaci"
#
#
# Topic 4:
# Words: 0.042*"sar" + 0.011*"chemokin" + 0.010*"cxcl" + 0.009*"peptid" + 0.008*"stimul" + 0.007*"monocyt" + 0.006*"defici" + 0.006*"assay" + 0.006*"astrocyt" + 0.006*"titer"
#
#
# Topic 5:
# ...

# %%
lda_model_0.save('lda_3_0.model')

# %% [markdown]
# Subtopic 1:

# %%
processed_docs=[]
for t in df_meta[df_meta.main_topic==1].abstract:
    processed_docs.append(preprocess(t))
    
dictionary = gensim.corpora.Dictionary(processed_docs)
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
lda_model_1 =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
for idx, topic in lda_model_1.print_topics(-1):
    print("Topic {}: \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic 0:
# Words: 0.022*"multiplex" + 0.012*"subtyp" + 0.010*"panel" + 0.008*"hybrid" + 0.007*"simultan" + 0.006*"tract" + 0.006*"case" + 0.006*"outbreak" + 0.006*"common" + 0.006*"set"
#
#
# Topic 1:
# Words: 0.043*"elisa" + 0.039*"sar" + 0.017*"serum" + 0.016*"sera" + 0.015*"enzym" + 0.013*"mer" + 0.011*"link" + 0.010*"immunosorb" + 0.009*"syndrom" + 0.009*"monoclon"
#
#
# Topic 2:
# Words: 0.024*"extract" + 0.009*"materi" + 0.008*"supplementari" + 0.008*"line" + 0.008*"mass" + 0.008*"antivir" + 0.006*"particl" + 0.006*"activ" + 0.006*"spectrometri" + 0.006*"bead"
#
#
# Topic 3:
# Words: 0.025*"chicken" + 0.020*"recombin" + 0.016*"avian" + 0.014*"bronchiti" + 0.011*"poultri" + 0.011*"protect" + 0.011*"genotyp" + 0.010*"vector" + 0.009*"serotyp" + 0.009*"group"
#
#
# Topic 4:
# Words: 0.023*"predict" + 0.015*"structur" + 0.012*"refer" + 0.010*"model" + 0.009*"algorithm" + 0.008*"databas" + 0.008*"accuraci" + 0.007*"pedv" + 0.007*"inform" + 0.007*"proteom"
#
#
# Topic 5:
# ...

# %%
lda_model_1.save('lda_3_1.model')

# %% [markdown]
# subtopic 2:

# %%
processed_docs=[]
for t in df_meta[df_meta.main_topic==2].abstract:
    processed_docs.append(preprocess(t))
    
dictionary = gensim.corpora.Dictionary(processed_docs)
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
lda_model_2 =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
for idx, topic in lda_model_2.print_topics(-1):
    print("Topic {}: \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic 0:
# Words: 0.029*"frameshift" + 0.027*"mrna" + 0.017*"ribosom" + 0.017*"frame" + 0.014*"read" + 0.013*"codon" + 0.012*"pseudoknot" + 0.011*"stem" + 0.010*"element" + 0.010*"open"
#
#
# Topic 1:
# Words: 0.032*"compound" + 0.018*"influenza" + 0.011*"potent" + 0.009*"evalu" + 0.009*"screen" + 0.009*"agent" + 0.008*"inhibitori" + 0.007*"resist" + 0.007*"treatment" + 0.007*"protect"
#
#
# Topic 2:
# Words: 0.016*"mab" + 0.015*"conform" + 0.010*"monoclon" + 0.009*"coil" + 0.009*"recogn" + 0.008*"helix" + 0.008*"helic" + 0.007*"trimer" + 0.007*"reactiv" + 0.007*"chang"
#
#
# Topic 3:
# Words: 0.013*"clone" + 0.011*"rna" + 0.011*"tgev" + 0.009*"cdna" + 0.008*"mrna" + 0.008*"delet" + 0.008*"virion" + 0.007*"particl" + 0.006*"purifi" + 0.006*"subgenom"
#
#
# Topic 4:
# Words: 0.020*"hcov" + 0.013*"rdrp" + 0.009*"assembl" + 0.009*"virion" + 0.008*"local" + 0.007*"particl" + 0.007*"cytoplasm" + 0.007*"signal" + 0.007*"golgi" + 0.007*"tail"
#
#
# Topic 5:
# ...

# %%
lda_model_2.save('lda_3_2.model')

# %% [markdown]
# Subtopic 3:

# %%
processed_docs=[]
for t in df_meta[df_meta.main_topic==3].abstract:
    processed_docs.append(preprocess(t))
    
dictionary = gensim.corpora.Dictionary(processed_docs)
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
lda_model_3 =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
for idx, topic in lda_model_3.print_topics(-1):
    print("Topic {}: \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic 0:
# Words: 0.016*"tgev" + 0.011*"express" + 0.011*"bcov" + 0.009*"virul" + 0.007*"bacteria" + 0.007*"gastroenter" + 0.006*"activ" + 0.006*"bacteri" + 0.006*"replic" + 0.006*"microbiota"
#
#
# Topic 1:
# Words: 0.024*"dog" + 0.017*"colostrum" + 0.016*"treatment" + 0.015*"milk" + 0.012*"calf" + 0.012*"canin" + 0.010*"concentr" + 0.008*"weight" + 0.007*"treat" + 0.007*"feed"
#
#
# Topic 2:
# Words: 0.039*"codon" + 0.030*"usag" + 0.023*"ccov" + 0.022*"pdcov" + 0.016*"pattern" + 0.014*"camel" + 0.013*"select" + 0.013*"bia" + 0.011*"evolut" + 0.011*"genotyp"
#
#
# Topic 3:
# Words: 0.021*"rotaviru" + 0.020*"coli" + 0.013*"cryptosporidium" + 0.013*"diarrhoea" + 0.010*"neonat" + 0.010*"calf" + 0.010*"oocyst" + 0.009*"herd" + 0.009*"parvum" + 0.009*"cattl"
#
#
# Topic 4:
# Words: 0.056*"herd" + 0.030*"elisa" + 0.024*"brsv" + 0.018*"tgev" + 0.015*"prcv" + 0.012*"cattl" + 0.012*"sera" + 0.010*"serolog" + 0.009*"seropreval" + 0.009*"risk"
#
#
# Topic 5:
# ...

# %%
lda_model_3.save('lda_3_3.model')

# %% [markdown]
# Subtopic 4:

# %%
processed_docs=[]
for t in df_meta[df_meta.main_topic==4].abstract:
    processed_docs.append(preprocess(t))
    
dictionary = gensim.corpora.Dictionary(processed_docs)
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
lda_model_4 =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
for idx, topic in lda_model_4.print_topics(-1):
    print("Topic {}: \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic 0:
# Words: 0.045*"asthma" + 0.044*"exacerb" + 0.018*"copd" + 0.014*"airway" + 0.010*"serum" + 0.009*"antibodi" + 0.009*"induc" + 0.008*"sputum" + 0.008*"subject" + 0.008*"chronic"
#
#
# Topic 1:
# Words: 0.030*"hmpv" + 0.011*"load" + 0.011*"metapneumoviru" + 0.011*"singl" + 0.010*"adenoviru" + 0.009*"pediatr" + 0.009*"lrti" + 0.008*"multipl" + 0.007*"design" + 0.007*"correl"
#
#
# Topic 2:
# Words: 0.025*"vaccin" + 0.020*"particip" + 0.020*"hadv" + 0.018*"trial" + 0.015*"dose" + 0.015*"transplant" + 0.011*"hajj" + 0.010*"pilgrim" + 0.008*"placebo" + 0.007*"corticosteroid"
#
#
# Topic 3:
# Words: 0.029*"hbov" + 0.012*"failur" + 0.011*"comorbid" + 0.011*"coinfect" + 0.010*"ventil" + 0.007*"speci" + 0.007*"condit" + 0.007*"bocaviru" + 0.007*"multipl" + 0.007*"chronic"
#
#
# Topic 4:
# Words: 0.017*"antibiot" + 0.013*"cultur" + 0.011*"hpiv" + 0.010*"etiolog" + 0.009*"multiplex" + 0.008*"agent" + 0.008*"rapid" + 0.008*"parainfluenza" + 0.008*"surveil" + 0.007*"throat"
#
#
# ...

# %%
lda_model_4.save('lda_3_4.model')

# %% [markdown]
# Subtopics of topic 5:

# %%
processed_docs=[]
for t in df_meta[df_meta.main_topic==5].abstract:
    processed_docs.append(preprocess(t))
    
dictionary = gensim.corpora.Dictionary(processed_docs)
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
lda_model_5 =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
for idx, topic in lda_model_5.print_topics(-1):
    print("Topic {}: \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic 0:
# Words: 0.011*"releas" + 0.010*"endosom" + 0.009*"stat" + 0.009*"epitheli" + 0.009*"virion" + 0.009*"mice" + 0.009*"particl" + 0.008*"fusion" + 0.008*"surfac" + 0.007*"envelop"
#
#
# Topic 1:
# Words: 0.031*"apoptosi" + 0.027*"ifitm" + 0.015*"phosphoryl" + 0.013*"stress" + 0.013*"caspas" + 0.012*"golgi" + 0.010*"apoptot" + 0.009*"sar" + 0.009*"death" + 0.008*"nuclear"
#
#
# Topic 2:
# Words: 0.015*"lncrna" + 0.015*"vaccin" + 0.010*"ebov" + 0.008*"ifn" + 0.007*"differenti" + 0.007*"sar" + 0.007*"adapt" + 0.006*"antibodi" + 0.006*"chang" + 0.006*"ebola"
#
#
# Topic 3:
# Words: 0.011*"ubiquitin" + 0.007*"proteasom" + 0.006*"proteas" + 0.006*"anti" + 0.006*"macrophag" + 0.006*"divers" + 0.005*"emerg" + 0.005*"cancer" + 0.005*"modif" + 0.005*"sar"
#
#
# Topic 4:
# Words: 0.021*"pedv" + 0.021*"cholesterol" + 0.016*"rnase" + 0.012*"lipid" + 0.011*"tgev" + 0.011*"porcin" + 0.011*"denv" + 0.010*"autophagi" + 0.009*"raft" + 0.009*"deplet"
#
#
# Topic 5:
# ...

# %%
lda_model_5.save('lda_3_5.model')

# %% [markdown]
# Subtopics of topic 6:

# %%
processed_docs=[]
for t in df_meta[df_meta.main_topic==6].abstract:
    processed_docs.append(preprocess(t))
    
dictionary = gensim.corpora.Dictionary(processed_docs)
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
lda_model_6 =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
for idx, topic in lda_model_6.print_topics(-1):
    print("Topic {}: \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic 0:
# Words: 0.019*"extract" + 0.009*"plant" + 0.008*"properti" + 0.007*"acid" + 0.007*"compound" + 0.007*"oxid" + 0.006*"nanoparticl" + 0.006*"antivir" + 0.006*"structur" + 0.005*"prepar"
#
#
# Topic 1:
# Words: 0.021*"ventil" + 0.020*"airborn" + 0.018*"room" + 0.014*"build" + 0.013*"droplet" + 0.012*"indoor" + 0.011*"wind" + 0.010*"flow" + 0.010*"pollut" + 0.008*"airflow"
#
#
# Topic 2:
# Words: 0.027*"mask" + 0.022*"filter" + 0.019*"respir" + 0.018*"influenza" + 0.012*"hospit" + 0.010*"care" + 0.010*"surgic" + 0.010*"worker" + 0.009*"hcw" + 0.008*"healthcar"
#
#
# Topic 3:
# Words: 0.025*"water" + 0.011*"calv" + 0.009*"hous" + 0.008*"male" + 0.008*"cage" + 0.007*"weight" + 0.007*"femal" + 0.007*"food" + 0.006*"popul" + 0.006*"microbi"
#
#
# Topic 4:
# Words: 0.018*"felv" + 0.015*"resist" + 0.013*"food" + 0.012*"antimicrobi" + 0.009*"antibodi" + 0.009*"antibiot" + 0.009*"speci" + 0.009*"host" + 0.008*"drug" + 0.007*"bacteri"
#
#
# Topic 5:
# ...

# %%
lda_model_6.save('lda_3_6.model')

# %% [markdown]
# Subtopics of topic 7:

# %%
processed_docs=[]
for t in df_meta[df_meta.main_topic==7].abstract:
    processed_docs.append(preprocess(t))
    
dictionary = gensim.corpora.Dictionary(processed_docs)
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
lda_model_7 =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
for idx, topic in lda_model_7.print_topics(-1):
    print("Topic {}: \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic 0:
# Words: 0.015*"travel" + 0.011*"ebola" + 0.009*"search" + 0.009*"medicin" + 0.008*"evid" + 0.008*"publish" + 0.008*"fever" + 0.007*"trial" + 0.006*"screen" + 0.006*"literatur"
#
#
# Topic 1:
# Words: 0.009*"govern" + 0.009*"train" + 0.009*"program" + 0.007*"servic" + 0.006*"capac" + 0.006*"resourc" + 0.006*"prepared" + 0.006*"nurs" + 0.005*"educ" + 0.005*"collabor"
#
#
# Topic 2:
# Words: 0.026*"anim" + 0.015*"laboratori" + 0.010*"virus" + 0.010*"zoonot" + 0.008*"environment" + 0.007*"avian" + 0.007*"speci" + 0.007*"product" + 0.006*"detect" + 0.006*"market"
#
#
# Topic 3:
# Words: 0.009*"contact" + 0.008*"spatial" + 0.008*"dynam" + 0.008*"predict" + 0.007*"pattern" + 0.007*"period" + 0.007*"simul" + 0.006*"paramet" + 0.006*"incid" + 0.006*"distribut"
#
#
# Topic 4:
# Words: 0.014*"mer" + 0.012*"particip" + 0.012*"survey" + 0.010*"nurs" + 0.010*"worker" + 0.010*"social" + 0.009*"media" + 0.008*"behavior" + 0.008*"questionnair" + 0.008*"healthcar"
#
#
# Topic 5:
# ...

# %%
lda_model_7.save('lda_3_7.model')

# %% [markdown]
# Remplissage sub_topics

# %% [markdown]
# Subtopics of topic 0:

# %%
dict_0 = lda_model_0.id2word

# %%
list_subtopics = []
for a in df_meta[df_meta.main_topic==0].abstract:
    bow_vector = dict_0.doc2bow(preprocess(a))
    list_score=[]
    for _, score in lda_model_0.get_document_topics(bow_vector, minimum_probability=0.0):
        list_score.append(score)
    list_subtopics.append(list_score)

# %%
df_topics_0=pd.DataFrame(list_subtopics, columns=['subtopic_0', 'subtopic_1', 'subtopic_2', 'subtopic_3', 'subtopic_4', 'subtopic_5', 'subtopic_6', 'subtopic_7'])
df_topics_0.set_index(df_meta[df_meta.main_topic==0].index, inplace=True)  
df_en_subtopics_0 = pd.concat([df_meta[df_meta.main_topic==0],df_topics_0], axis=1)

# %%
df_en_subtopics_0
# Out:
#        cord_uid                                                sha  source_x  \
# 13     lcpp5fim           8cfb8dfc2f8b2c6e1d60ff48da02de6670694869   biorxiv
# 18     2eh0bhee           1c0b25c8e3c89243fd8797e2e964e12689bc8556   biorxiv
# 27     pxpujrhx           44a440cc1c135c938d2216ea672f8ef4f9c01296   biorxiv
# 34     lj0ar2v5           28b107243576723248ad4053261000311a22f134   biorxiv
# 36     phmm596b           dff716159738acd6bd53b4be12af45358a58752e   biorxiv
# 37     iedh762s           8c900409a679dc1f16ef13c73500cbb53605b683   biorxiv
# 47     jopeo9gs           0cb9c296684ca5e71462d825cab2827854a01544   biorxiv
# 49     pt0kes0s           88e3b43319399c339186c02c44d369228c35eef4   biorxiv
# 117    ely200x3           aef0734eb2538d3624d650a4ae20c3f66cace5f2   biorxiv
# 156    xo5u02d7           6c91b00faa16142426820016ad3a7847fc77c8e4   biorxiv
# 169    xtmozkf6           f5d9ab798adf8face1655d476644ebb75fbfef18   medrxiv
# ...

# %%
# Pour obtenir le main subtopic dans une nouvelle colonne:
subtopic_strings = []
for i in range(0, 8):
    subtopic_strings.append('subtopic_' + repr(i))

df_en_subtopics_0['main_subtopic'] = df_en_subtopics_0[subtopic_strings].idxmax(axis=1).str[-1:]

# %%
df_en_subtopics_0
# Out:
#        cord_uid                                                sha  source_x  \
# 13     lcpp5fim           8cfb8dfc2f8b2c6e1d60ff48da02de6670694869   biorxiv
# 18     2eh0bhee           1c0b25c8e3c89243fd8797e2e964e12689bc8556   biorxiv
# 27     pxpujrhx           44a440cc1c135c938d2216ea672f8ef4f9c01296   biorxiv
# 34     lj0ar2v5           28b107243576723248ad4053261000311a22f134   biorxiv
# 36     phmm596b           dff716159738acd6bd53b4be12af45358a58752e   biorxiv
# 37     iedh762s           8c900409a679dc1f16ef13c73500cbb53605b683   biorxiv
# 47     jopeo9gs           0cb9c296684ca5e71462d825cab2827854a01544   biorxiv
# 49     pt0kes0s           88e3b43319399c339186c02c44d369228c35eef4   biorxiv
# 117    ely200x3           aef0734eb2538d3624d650a4ae20c3f66cace5f2   biorxiv
# 156    xo5u02d7           6c91b00faa16142426820016ad3a7847fc77c8e4   biorxiv
# 169    xtmozkf6           f5d9ab798adf8face1655d476644ebb75fbfef18   medrxiv
# ...

# %% [markdown]
# Subtopics of topic 1:

# %%
dict_1 = lda_model_1.id2word

# %%
list_subtopics = []
for a in df_meta[df_meta.main_topic==1].abstract:
    bow_vector = dict_1.doc2bow(preprocess(a))
    list_score=[]
    for _, score in lda_model_1.get_document_topics(bow_vector, minimum_probability=0.0):
        list_score.append(score)
    list_subtopics.append(list_score)

# %%
df_topics_1=pd.DataFrame(list_subtopics, columns=['subtopic_0', 'subtopic_1', 'subtopic_2', 'subtopic_3', 'subtopic_4', 'subtopic_5', 'subtopic_6', 'subtopic_7'])
df_topics_1.set_index(df_meta[df_meta.main_topic==1].index, inplace=True)  
df_en_subtopics_1 = pd.concat([df_meta[df_meta.main_topic==1],df_topics_1], axis=1)

# %%
df_en_subtopics_1
# Out:
#        cord_uid                                                sha  source_x  \
# 0      vho70jcx           f056da9c64fbf00a4645ae326e8a4339d015d155   biorxiv
# 2      62gfisc6           f33c6d94b0efaa198f8f3f20e644625fa3fe10d2   biorxiv
# 3      058r9486           4da8a87e614373d56070ed272487451266dce919   biorxiv
# 11     nljskxut                                                NaN   biorxiv
# 15     csokkcqq           a59906b732bf4a489e282c3e4f499d4166c622e7   biorxiv
# 52     7xmn8yvc                                                NaN   biorxiv
# 69     uw76y16g           9b17a9fa6be11d8b3dbed9f3dea2516020083bd3   biorxiv
# 74     bqwmx5dy           93f67ffe7803061de9b19c4dfa346b3aa97aa4eb   biorxiv
# 75     eohjkqc4                                                NaN   biorxiv
# 78     e5p4metz           8c223fd63ba6a924ecd3df8d32bcf0556758cb95   biorxiv
# 87     wtarrhf0           0624a12abfe85c8b5070850d912a2db4cd453236   biorxiv
# ...

# %%
# Pour obtenir le main subtopic dans une nouvelle colonne:
subtopic_strings = []
for i in range(0, 8):
    subtopic_strings.append('subtopic_' + repr(i))

df_en_subtopics_1['main_subtopic'] = df_en_subtopics_1[subtopic_strings].idxmax(axis=1).str[-1:]

# %%
df_en_subtopics_1
# Out:
#        cord_uid                                                sha  source_x  \
# 0      vho70jcx           f056da9c64fbf00a4645ae326e8a4339d015d155   biorxiv
# 2      62gfisc6           f33c6d94b0efaa198f8f3f20e644625fa3fe10d2   biorxiv
# 3      058r9486           4da8a87e614373d56070ed272487451266dce919   biorxiv
# 11     nljskxut                                                NaN   biorxiv
# 15     csokkcqq           a59906b732bf4a489e282c3e4f499d4166c622e7   biorxiv
# 52     7xmn8yvc                                                NaN   biorxiv
# 69     uw76y16g           9b17a9fa6be11d8b3dbed9f3dea2516020083bd3   biorxiv
# 74     bqwmx5dy           93f67ffe7803061de9b19c4dfa346b3aa97aa4eb   biorxiv
# 75     eohjkqc4                                                NaN   biorxiv
# 78     e5p4metz           8c223fd63ba6a924ecd3df8d32bcf0556758cb95   biorxiv
# 87     wtarrhf0           0624a12abfe85c8b5070850d912a2db4cd453236   biorxiv
# ...

# %% [markdown]
# Subtopics of topic 2:

# %%
dict_2 = lda_model_2.id2word

# %%
list_subtopics = []
for a in df_meta[df_meta.main_topic==2].abstract:
    bow_vector = dict_2.doc2bow(preprocess(a))
    list_score=[]
    for _, score in lda_model_2.get_document_topics(bow_vector, minimum_probability=0.0):
        list_score.append(score)
    list_subtopics.append(list_score)

# %%
df_topics_2=pd.DataFrame(list_subtopics, columns=['subtopic_0', 'subtopic_1', 'subtopic_2', 'subtopic_3', 'subtopic_4', 'subtopic_5', 'subtopic_6', 'subtopic_7'])
df_topics_2.set_index(df_meta[df_meta.main_topic==2].index, inplace=True)  
df_en_subtopics_2 = pd.concat([df_meta[df_meta.main_topic==2],df_topics_2], axis=1)

# %%
df_en_subtopics_2
# Out:
#        cord_uid                                                sha  source_x  \
# 9      4xocqn6o           1f9d3f9a1a0e8db6a086e0a2b5ba50cf9f235dae   biorxiv
# 16     08mep8hm           99dab788e984601ee4efcd1138926caf10c00dcf   biorxiv
# 22     t3tm6f9p           c04e10858012bdd666d50c0d69c3d1e7224ccbea   biorxiv
# 31     l82aakrk           f9b108c052ded463773a9838a8157ac7d5ba6d1a   biorxiv
# 32     gfiukh90           5b27a16123f46b5aaeda3171d22e075dcbd36ee6   biorxiv
# 33     mkoyc7wh                                                NaN   biorxiv
# 44     mudv1ejd           b4fc44eabb1f640124fff98990c85dc5c9984aee   biorxiv
# 46     0abutzb3           d91120d80916351170b34715ea4ab141f02c51fb   biorxiv
# 48     4it5c9n2           f122e125c2cd3580b1a38e27c780b99f671fd78f   biorxiv
# 60     v7asfaxc           656ef218f7dcea5555a59cdc29d0f9ec8d5c2a82   biorxiv
# 61     vqtx98xm           f126b7f9c8ba02a0f872b51cf95d08086e0bd4ac   biorxiv
# ...

# %%
# Pour obtenir le main subtopic dans une nouvelle colonne:
subtopic_strings = []
for i in range(0, 8):
    subtopic_strings.append('subtopic_' + repr(i))

df_en_subtopics_2['main_subtopic'] = df_en_subtopics_2[subtopic_strings].idxmax(axis=1).str[-1:]

# %% [markdown]
# Subtopics of topic 3:

# %%
dict_3 = lda_model_3.id2word

# %%
list_subtopics = []
for a in df_meta[df_meta.main_topic==3].abstract:
    bow_vector = dict_3.doc2bow(preprocess(a))
    list_score=[]
    for _, score in lda_model_3.get_document_topics(bow_vector, minimum_probability=0.0):
        list_score.append(score)
    list_subtopics.append(list_score)

# %%
df_topics_3=pd.DataFrame(list_subtopics, columns=['subtopic_0', 'subtopic_1', 'subtopic_2', 'subtopic_3', 'subtopic_4', 'subtopic_5', 'subtopic_6', 'subtopic_7'])
df_topics_3.set_index(df_meta[df_meta.main_topic==3].index, inplace=True)  
df_en_subtopics_3 = pd.concat([df_meta[df_meta.main_topic==3],df_topics_3], axis=1)

# %%
df_en_subtopics_3
# Out:
#        cord_uid                                                sha  source_x  \
# 14     gjxumrmm           6499f5c865c3db3bdfc1e969ea940a80d547a5bb   biorxiv
# 19     76i8yvb4           d1b26388670660f66249b55ece2beccee4c18d1a   biorxiv
# 23     57sp9d9l           5570cb9ff2905fda60cfd6e94f3c32774b765265   biorxiv
# 40     pl7t3hca           e0fd364797eb02a280e25e2649dfe6d6c0d33e05   biorxiv
# 67     npd2qf7m           44b6eea3629b4e13595dc49813ee39a0d20dc5f2   biorxiv
# 72     43cxzudl                                                NaN   biorxiv
# 83     ts91ivwf           106f10eaae4fb67aca5b2bd737ce2bf1c27fa243   biorxiv
# 96     o47v5vgw                                                NaN   biorxiv
# 113    k2qj6o7j                                                NaN   biorxiv
# 193    hwvr0v8c           329dfdd2fbe4b3c510c5329219bfd33764ab1710   biorxiv
# 259    9aegg5sd           1df9ce60e358f6cef0be3f6e15fe2a9c6f93f39c   biorxiv
# ...

# %%
# Pour obtenir le main subtopic dans une nouvelle colonne:
subtopic_strings = []
for i in range(0, 8):
    subtopic_strings.append('subtopic_' + repr(i))

df_en_subtopics_3['main_subtopic'] = df_en_subtopics_3[subtopic_strings].idxmax(axis=1).str[-1:]

# %% [markdown]
# Subtopics of topic 4:

# %%
dict_4 = lda_model_4.id2word

# %%
list_subtopics = []
for a in df_meta[df_meta.main_topic==4].abstract:
    bow_vector = dict_4.doc2bow(preprocess(a))
    list_score=[]
    for _, score in lda_model_4.get_document_topics(bow_vector, minimum_probability=0.0):
        list_score.append(score)
    list_subtopics.append(list_score)

# %%
df_topics_4=pd.DataFrame(list_subtopics, columns=['subtopic_0', 'subtopic_1', 'subtopic_2', 'subtopic_3', 'subtopic_4', 'subtopic_5', 'subtopic_6', 'subtopic_7'])
df_topics_4.set_index(df_meta[df_meta.main_topic==4].index, inplace=True)  
df_en_subtopics_4 = pd.concat([df_meta[df_meta.main_topic==4],df_topics_4], axis=1)

# %%
df_en_subtopics_4
# Out:
#        cord_uid                                                sha  source_x  \
# 5      z3tgnzth           c41fdb2efd6d61384a92a84cbba3f8233629a41b   biorxiv
# 8      wafvnbdu           3461d71f6890f7e5ba53bf168be3945cdb16d901   biorxiv
# 39     ahdz5078           8eb99586e9103599ab2f58cc33ca94cd0b60ae53   biorxiv
# 41     km0b1z64           d418cdee18b07a0adfb553d43b4a08f7736fa9f3   biorxiv
# 45     d0y1hs88                                                NaN   biorxiv
# 59     8xcplab3           fb7371ad31cd501854660876a282060402082537   biorxiv
# 62     pgfdy23h           7116ddab89281e7641fb659019c90ee3715f5039   biorxiv
# 110    ykofrn9i           cbc05d14c57b91081970a232ab83bc993f998fe2   medrxiv
# 114    u8goc7io           12fac9aedb1a09a3922a3c084ce4723708e463d6   medrxiv
# 149    rj9k9awy                                                NaN   medrxiv
# 150    vspnuxz9           a1bff76ce360e8990b0a4ee2a5228a6e6e63d9c1   medrxiv
# ...

# %%
# Pour obtenir le main subtopic dans une nouvelle colonne:
subtopic_strings = []
for i in range(0, 8):
    subtopic_strings.append('subtopic_' + repr(i))

df_en_subtopics_4['main_subtopic'] = df_en_subtopics_4[subtopic_strings].idxmax(axis=1).str[-1:]

# %% [markdown]
# Subtopics of topic 5:

# %%
dict_5 = lda_model_5.id2word

# %%
list_subtopics = []
for a in df_meta[df_meta.main_topic==5].abstract:
    bow_vector = dict_5.doc2bow(preprocess(a))
    list_score=[]
    for _, score in lda_model_5.get_document_topics(bow_vector, minimum_probability=0.0):
        list_score.append(score)
    list_subtopics.append(list_score)

# %%
df_topics_5=pd.DataFrame(list_subtopics, columns=['subtopic_0', 'subtopic_1', 'subtopic_2', 'subtopic_3', 'subtopic_4', 'subtopic_5', 'subtopic_6', 'subtopic_7'])
df_topics_5.set_index(df_meta[df_meta.main_topic==5].index, inplace=True)  
df_en_subtopics_5 = pd.concat([df_meta[df_meta.main_topic==5],df_topics_5], axis=1)

# %%
df_en_subtopics_5
# Out:
#        cord_uid                                                sha  source_x  \
# 10     q5iylws9           01e3b313e78a352593be2ff64927192af66619b5   biorxiv
# 20     omtmy9z6                                                NaN   biorxiv
# 21     2cerplno           53442eacc3f233078507fa37b78267399e8c1e3b   biorxiv
# 26     1znuxoj5           fd3fc2c49f5cc27e4262261d0c9045911d65cb6e   biorxiv
# 42     ois9fiuq                                                NaN   biorxiv
# 43     9pa51d9x           95754ec84bdee0637765a5ee34983a5f6cc86eed   biorxiv
# 50     9e3z9xdd           0b4b4e5bb8d0d5167eec1e203b5dad283bd364a5   biorxiv
# 51     9y8r277c           90e28ff462882ca7a9329beb879f73c2e99430e4   biorxiv
# 53     jhwjh12k           7a51b191fd6575831585eee67a0ac67f209d8fcb   biorxiv
# 57     jzzhpw7h           3b22eecad8a582436c52284a4db2198a98a94e18   biorxiv
# 58     yqa7ggqg           5d9e490190986584d799e2828c6fd9679e5ae159   biorxiv
# ...

# %%
# Pour obtenir le main subtopic dans une nouvelle colonne:
subtopic_strings = []
for i in range(0, 8):
    subtopic_strings.append('subtopic_' + repr(i))

df_en_subtopics_5['main_subtopic'] = df_en_subtopics_5[subtopic_strings].idxmax(axis=1).str[-1:]

# %% [markdown]
# Subtopics of topic 6:

# %%
dict_6 = lda_model_6.id2word

# %%
list_subtopics = []
for a in df_meta[df_meta.main_topic==6].abstract:
    bow_vector = dict_6.doc2bow(preprocess(a))
    list_score=[]
    for _, score in lda_model_6.get_document_topics(bow_vector, minimum_probability=0.0):
        list_score.append(score)
    list_subtopics.append(list_score)

# %%
df_topics_6=pd.DataFrame(list_subtopics, columns=['subtopic_0', 'subtopic_1', 'subtopic_2', 'subtopic_3', 'subtopic_4', 'subtopic_5', 'subtopic_6', 'subtopic_7'])
df_topics_6.set_index(df_meta[df_meta.main_topic==6].index, inplace=True)  
df_en_subtopics_6 = pd.concat([df_meta[df_meta.main_topic==6],df_topics_6], axis=1)

# %%
df_en_subtopics_6
# Out:
#        cord_uid                                                sha  source_x  \
# 38     2179jaes           6aa2716c00d89f4b760a9167b15d6203303ae6b9   biorxiv
# 56     j5gjipdn                                                NaN   biorxiv
# 178    77nsidzc           4c24ee4a86de1d5207d93ce39132f7b660cf82e0   biorxiv
# 359    qc1mpzli                                                NaN   medrxiv
# 400    lad31adx           eca1cf50bd67a7efbcaf78864f5f5b3b850243d6   medrxiv
# 420    zriuh5q5           691da9d5576aa959e22114a1ebb35548efd276a0   medrxiv
# 491    i7tjno0w           b53dd68cad40cbcd698a848f53853e5f03d44a1f   medrxiv
# 562    dtoheyo4           8a73ab00fcfa1789da4d0755f67bc5da48846ace   medrxiv
# 596    h2h4bnd5           2989bf36068372cfedef82f58f4777e60ccbcfaa   biorxiv
# 649    rike3ukb           254c1e4d661d7fb5954c855387595c3cde0e8156   medrxiv
# 656    uj0i2anr           2ae710bf5f60c23c489e4c61245a35a4f85178cb   medrxiv
# ...

# %%
# Pour obtenir le main subtopic dans une nouvelle colonne:
subtopic_strings = []
for i in range(0, 8):
    subtopic_strings.append('subtopic_' + repr(i))

df_en_subtopics_6['main_subtopic'] = df_en_subtopics_6[subtopic_strings].idxmax(axis=1).str[-1:]

# %% [markdown]
# Subtopics of topic 7:

# %%
dict_7 = lda_model_7.id2word

# %%
list_subtopics = []
for a in df_meta[df_meta.main_topic==7].abstract:
    bow_vector = dict_7.doc2bow(preprocess(a))
    list_score=[]
    for _, score in lda_model_7.get_document_topics(bow_vector, minimum_probability=0.0):
        list_score.append(score)
    list_subtopics.append(list_score)

# %%
df_topics_7=pd.DataFrame(list_subtopics, columns=['subtopic_0', 'subtopic_1', 'subtopic_2', 'subtopic_3', 'subtopic_4', 'subtopic_5', 'subtopic_6', 'subtopic_7'])
df_topics_7.set_index(df_meta[df_meta.main_topic==7].index, inplace=True)  
df_en_subtopics_7 = pd.concat([df_meta[df_meta.main_topic==7],df_topics_7], axis=1)

# %%
df_en_subtopics_7
# Out:
#        cord_uid                                                sha  source_x  \
# 1      i9tbix2v           daf32e013d325a6feb80e83d15aabc64a48fae33   biorxiv
# 4      wich35l7           eccef80cfbe078235df22398f195d5db462d8000   biorxiv
# 6      1xxrnpg3           1dd898b5ca1ae70ec0e3cad89fc87a165002a99e   biorxiv
# 7      8ilzm51q           33565294e6bc67fb7ee14dcae6cfdb08148f4ea5   biorxiv
# 12     lfm6erzy           3b73c8abb7528c958cec0bae1890828af007b599   biorxiv
# 17     ejqq2wmi           97339c9d365437d54ea33be1a1b634d35f460208   biorxiv
# 24     tiyjmih7           45f184e736c4a857bc0e3df0d55962f743c1493a   biorxiv
# 25     30kwl4rj           ffbf8ea9948d73572fd052a74afa01b19e6758a3   biorxiv
# 28     2j4z5rp8           9b5f5119bbfbded3245acc37859cefde967458e7   biorxiv
# 29     kxe65hd7                                                NaN   biorxiv
# 30     8elmjre9           8f4b98da50277e6c9516aef0227f5cca9af6b5e8   biorxiv
# ...

# %%
# Pour obtenir le main subtopic dans une nouvelle colonne:
subtopic_strings = []
for i in range(0, 8):
    subtopic_strings.append('subtopic_' + repr(i))

df_en_subtopics_7['main_subtopic'] = df_en_subtopics_7[subtopic_strings].idxmax(axis=1).str[-1:]

# %% [markdown]
# Add all subtopics of all topics:

# %%
df_en_subtopics_final = pd.concat([df_en_subtopics_0,df_en_subtopics_1, df_en_subtopics_2, df_en_subtopics_3, df_en_subtopics_4, df_en_subtopics_5, df_en_subtopics_6, df_en_subtopics_7], axis=0)

# %%
df_en_subtopics_final.to_csv('metadata_en_topics_and_subtopics.csv', index=False)

# %%
df_en_subtopics_final
# Out:
#        cord_uid                                                sha  source_x  \
# 13     lcpp5fim           8cfb8dfc2f8b2c6e1d60ff48da02de6670694869   biorxiv
# 18     2eh0bhee           1c0b25c8e3c89243fd8797e2e964e12689bc8556   biorxiv
# 27     pxpujrhx           44a440cc1c135c938d2216ea672f8ef4f9c01296   biorxiv
# 34     lj0ar2v5           28b107243576723248ad4053261000311a22f134   biorxiv
# 36     phmm596b           dff716159738acd6bd53b4be12af45358a58752e   biorxiv
# 37     iedh762s           8c900409a679dc1f16ef13c73500cbb53605b683   biorxiv
# 47     jopeo9gs           0cb9c296684ca5e71462d825cab2827854a01544   biorxiv
# 49     pt0kes0s           88e3b43319399c339186c02c44d369228c35eef4   biorxiv
# 117    ely200x3           aef0734eb2538d3624d650a4ae20c3f66cace5f2   biorxiv
# 156    xo5u02d7           6c91b00faa16142426820016ad3a7847fc77c8e4   biorxiv
# 169    xtmozkf6           f5d9ab798adf8face1655d476644ebb75fbfef18   medrxiv
# ...
